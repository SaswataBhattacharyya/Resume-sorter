# %%
import os
from docx import Document
from lxml import etree
import win32com.client  # For handling .doc files

# Function to extract text from shapes (text boxes) and join with spaces
def extract_text_from_shapes_and_textboxes(doc):
    extracted_text = []

    # Extract text from textboxes using XML
    for shape in doc.element.xpath('.//w:txbxContent//w:t'):
        extracted_text.append(shape.text)

    return ' '.join(extracted_text).strip()  # Join text with space and remove extra spaces

# Function to extract text from headers and footers and join with spaces
def extract_text_from_headers_and_footers(doc):
    extracted_text = []

    for section in doc.sections:
        # Extract header text
        for paragraph in section.header.paragraphs:
            extracted_text.append(paragraph.text)
        # Extract footer text
        for paragraph in section.footer.paragraphs:
            extracted_text.append(paragraph.text)

    return ' '.join(extracted_text).strip()  # Join text with space and remove extra spaces

# Function to extract text from .doc files using pywin32
def doc_to_txt(input_path, output_path):
    try:
        word = win32com.client.Dispatch("Word.Application")
        doc = word.Documents.Open(input_path)
        doc_text = doc.Content.Text
        doc.Close()
        word.Quit()

        with open(output_path, "w", encoding="utf-8") as txt_file:
            txt_file.write(doc_text)

        print(f"Converted: {input_path} -> {output_path}")
    except Exception as e:
        print(f"Error converting {input_path}: {e}")

# Function to convert DOCX and DOC files to TXT
def convert_docs_to_txt(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")

        if filename.endswith(".docx"):
            try:
                doc = Document(input_path)
                
                # Extract regular text from paragraphs
                extracted_text = [paragraph.text for paragraph in doc.paragraphs]
                
                # Extract text from tables
                for table in doc.tables:
                    for row in table.rows:
                        row_data = [cell.text.strip() for cell in row.cells]
                        extracted_text.append(' '.join(row_data))
                
                # Extract text from shapes and textboxes (joined with spaces)
                shapes_text = extract_text_from_shapes_and_textboxes(doc)
                if shapes_text:
                    extracted_text.append(shapes_text)
                
                # Extract text from headers and footers (joined with spaces)
                headers_footers_text = extract_text_from_headers_and_footers(doc)
                if headers_footers_text:
                    extracted_text.append(headers_footers_text)
                
                # Save all extracted text to a .txt file
                with open(output_path, "w", encoding="utf-8") as txt_file:
                    txt_file.write('\n'.join([text for text in extracted_text if text.strip()]))  # Keep normal text separate
                
                print(f"Converted: {filename} -> {output_path}")
            except Exception as e:
                print(f"Error converting {filename}: {e}")

        elif filename.endswith(".doc"):
            doc_to_txt(input_path, output_path)

# Folder paths
input_folder = r"C:\Users\polpi\Desktop\data science\project\docker_project\resumes"
output_folder = r"C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt"

# Run the function
convert_docs_to_txt(input_folder, output_folder)
# Out:
# Converted: Anil kumar.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Anil kumar.txt
# Converted: AradhanaTripathi[4_0].docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\AradhanaTripathi[4_0].txt
# Converted: Buddha Vamsi.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Buddha Vamsi.txt
# Converted: ChinnaSubbarayuduM_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\ChinnaSubbarayuduM_Hexaware.txt
# Converted: Gopi Krishna_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Gopi Krishna_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Hari Krishna M_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Hari Krishna M_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Harikrishna Akula_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Harikrishna Akula_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Hima Mendu_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Hima Mendu_Hexaware.txt
# Converted: Himaja G_(Hexaware).docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Himaja G_(Hexaware).txt
# Converted: Internship_Ravali_Musquare Technologies (1).docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Internship_Ravali_Musquare Technologies (1).txt
# Converted: Internship_Susovan Bag_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Internship_Susovan Bag_Musquare Technologies.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\J. Sumanth Royal_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\J. Sumanth Royal_Hexaware.txt
# Converted: Jyotiverma_Heaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Jyotiverma_Heaware.txt
# Converted: kamballapradeep.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\kamballapradeep.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Madeeswar A_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Madeeswar A_Hexaware.txt
# Converted: MooraboyinaGuravaiah_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\MooraboyinaGuravaiah_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Naresh Babu Cherukuri_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Naresh Babu Cherukuri_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Nazeer Basha.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Nazeer Basha.txt
# Converted: Neeraj Mishra.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Neeraj Mishra.txt
# Converted: P V Sai Krishna_ Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\P V Sai Krishna_ Hexaware.txt
# Converted: Peoplesoft Admin_AnubhavSingh.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_AnubhavSingh.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Admin_G Ananda Rayudu.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_G Ananda Rayudu.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Admin_Gangareddy.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_Gangareddy.txt
# Converted: Peoplesoft Admin_Murali.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_Murali.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Admin_Priyanka Ramadoss.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_Priyanka Ramadoss.txt
# Converted: Peoplesoft Admin_SirazuddinMohammad.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_SirazuddinMohammad.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Admin_srinivasarao.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_srinivasarao.txt
# Converted: Peoplesoft Admin_Varkala Vikas.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_Varkala Vikas.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Admin_Vinod Akkala.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Admin_Vinod Akkala.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\PeopleSoft DBA_Ganesh Alladi.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\PeopleSoft DBA_Ganesh Alladi.txt
# Converted: PeopleSoft DBA_Vivekanand Sayana.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\PeopleSoft DBA_Vivekanand Sayana.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Finance_Arun Venu.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Finance_Arun Venu.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Finance_Pritam Biswas.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Finance_Pritam Biswas.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft Finance_Rahul Ahuja.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft Finance_Rahul Ahuja.txt
# Converted: Peoplesoft FSCM_HariNarayana.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft FSCM_HariNarayana.txt
# Converted: Peoplesoft FSCM_Murali.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft FSCM_Murali.txt
# Converted: Peoplesoft FSCM_PriyabrataHota.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft FSCM_PriyabrataHota.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Peoplesoft FSCM_R Ahmed.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft FSCM_R Ahmed.txt
# Converted: Peoplesoft FSCM_SUJATHA.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Peoplesoft FSCM_SUJATHA.txt
# Converted: premsai.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\premsai.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Priyanka L.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Priyanka L.txt
# Converted: PSyamKumar[2_3].docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\PSyamKumar[2_3].txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Punugoti Swetha_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Punugoti Swetha_Hexaware.txt
# Converted: RahulM_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\RahulM_Hexaware.txt
# Converted: Rajupavanakumari[2_10].docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Rajupavanakumari[2_10].txt
# Converted: Ramalakshmi K.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Ramalakshmi K.txt
# Converted: RameshNataru[3_4].docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\RameshNataru[3_4].txt
# Converted: RameshP_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\RameshP_Hexaware.txt
# Converted: React Developer_Deepakreddy.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Deepakreddy.txt
# Converted: React Developer_Haripriya.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Haripriya.txt
# Converted: React Developer_Kamalakar Reddy.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Kamalakar Reddy.txt
# Converted: React Developer_Naveen sadhu.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Naveen sadhu.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\React Developer_PavasGoswami.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_PavasGoswami.txt
# Converted: React Developer_Pragnya.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Pragnya.txt
# Converted: React Developer_Sarala Madasu-converted.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Sarala Madasu-converted.txt
# Converted: React Developer_Thirupathiamma.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Thirupathiamma.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\React Developer_Vinay Reddy.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Developer_Vinay Reddy.txt
# Converted: React Dev_Krishna Kanth.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Dev_Krishna Kanth.txt
# Converted: React Dev_Krishna Kanth_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React Dev_Krishna Kanth_Musquare Technologies.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\React JS Developer_AnjaniPriyadarshini.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React JS Developer_AnjaniPriyadarshini.txt
# Converted: React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.txt
# Converted: React JS Developer_Venkatalakshmi (1)-converted.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\React JS Developer_Venkatalakshmi (1)-converted.txt
# Converted: Reactjs Developer_kambala sai surendra_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_kambala sai surendra_Musquare Technologies.txt
# Converted: Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_M Lokesh Babu_Musquare Technologies.txt
# Converted: Reactjs Developer_M Lokesh.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_M Lokesh.txt
# Converted: Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.txt
# Converted: Reactjs Developer_Prabakaran_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_Prabakaran_Musquare Technologies.txt
# Converted: Reactjs Developer_Pranish Sonone_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_Pranish Sonone_Musquare Technologies.txt
# Converted: Reactjs Developer_Ranga Gaganam_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_Ranga Gaganam_Musquare Technologies.txt
# Converted: Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.txt
# Converted: Resume_Subha Santosh_Peoplesoft FSCM.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Resume_Subha Santosh_Peoplesoft FSCM.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\ShireeshKumar_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\ShireeshKumar_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Sri Krishna S_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Sri Krishna S_Hexaware.txt
# Converted: Srikanth-Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Srikanth-Hexaware.txt
# Converted: SSKumar_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\SSKumar_Hexaware.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Tatikonda Kiran Kumar.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Tatikonda Kiran Kumar.txt
# Converted: C:\Users\polpi\Desktop\data science\project\docker_project\resumes\Venkateswarlu B_Hexaware.doc -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Venkateswarlu B_Hexaware.txt
# Converted: Vinay Kumar_Hexaware.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Vinay Kumar_Hexaware.txt
# Converted: Vinod B.docx -> C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt\Vinod B.txt

# %%
import os
from docx import Document
from lxml import etree
import win32com.client  # For handling .doc files
from PyPDF2 import PdfReader  # For handling .pdf files

# Function to extract text from shapes (text boxes) and join with spaces
def extract_text_from_shapes_and_textboxes(doc):
    extracted_text = []

    # Extract text from textboxes using XML
    for shape in doc.element.xpath('.//w:txbxContent//w:t'):
        extracted_text.append(shape.text)

    return ' '.join(extracted_text).strip()  # Join text with space and remove extra spaces

# Function to extract text from headers and footers and join with spaces
def extract_text_from_headers_and_footers(doc):
    extracted_text = []

    for section in doc.sections:
        # Extract header text
        for paragraph in section.header.paragraphs:
            extracted_text.append(paragraph.text)
        # Extract footer text
        for paragraph in section.footer.paragraphs:
            extracted_text.append(paragraph.text)

    return ' '.join(extracted_text).strip()  # Join text with space and remove extra spaces

# Function to extract text from .doc files using pywin32
def doc_to_txt(input_path, output_path):
    try:
        word = win32com.client.Dispatch("Word.Application")
        doc = word.Documents.Open(input_path)
        doc_text = doc.Content.Text
        doc.Close()
        word.Quit()

        with open(output_path, "w", encoding="utf-8") as txt_file:
            txt_file.write(doc_text)

        print(f"Converted: {input_path} -> {output_path}")
    except Exception as e:
        print(f"Error converting {input_path}: {e}")

# Function to extract text from PDF files
def pdf_to_txt(input_path, output_path):
    try:
        reader = PdfReader(input_path)
        extracted_text = []

        for page in reader.pages:
            extracted_text.append(page.extract_text())

        with open(output_path, "w", encoding="utf-8") as txt_file:
            txt_file.write('\n'.join(extracted_text))

        print(f"Converted: {input_path} -> {output_path}")
    except Exception as e:
        print(f"Error converting {input_path}: {e}")

# Function to convert DOCX, DOC, and PDF files to TXT
def convert_files_to_txt(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")

        if filename.endswith(".docx"):
            try:
                doc = Document(input_path)

                # Extract text from shapes and textboxes (joined with spaces)
                shapes_text = extract_text_from_shapes_and_textboxes(doc)

                # Extract text from headers and footers (joined with spaces)
                headers_footers_text = extract_text_from_headers_and_footers(doc)
                
                # Extract regular text from paragraphs
                paragraphs_text = [paragraph.text for paragraph in doc.paragraphs]

                # Extract text from tables
                for table in doc.tables:
                    for row in table.rows:
                        row_data = [cell.text.strip() for cell in row.cells]
                        paragraphs_text.append(' '.join(row_data))
                
                # Combine all extracted text with the specified order
                combined_text = []
                if shapes_text:
                    combined_text.append(shapes_text)
                if headers_footers_text:
                    combined_text.append(headers_footers_text)
                combined_text.extend([text for text in paragraphs_text if text.strip()])
                
                # Save all extracted text to a .txt file
                with open(output_path, "w", encoding="utf-8") as txt_file:
                    txt_file.write('\n'.join(combined_text))
                
                print(f"Converted: {filename} -> {output_path}")
            except Exception as e:
                print(f"Error converting {filename}: {e}")

        elif filename.endswith(".doc"):
            doc_to_txt(input_path, output_path)

        elif filename.endswith(".pdf"):
            pdf_to_txt(input_path, output_path)

# Folder paths
input_folder = r"C:\Users\polpi\Desktop\data science\project\docker_project\resumes"
output_folder = r"C:\Users\polpi\Desktop\data science\project\docker_project\resume_txt"

# Run the function
convert_files_to_txt(input_folder, output_folder)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 from lxml import etree
#       4 import win32com.client  # For handling .doc files
# ----> 5 from PyPDF2 import PdfReader  # For handling .pdf files
#       7 # Function to extract text from shapes (text boxes) and join with spaces
#       8 def extract_text_from_shapes_and_textboxes(doc):
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Note: you may need to restart the kernel to use updated packages.
